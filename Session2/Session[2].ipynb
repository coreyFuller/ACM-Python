# %% [markdown]
# #**Review from last Session**

# %%
#Complete the code


x = 4 
y = 7

#print the sum of these numbers
print(      )


#declare a list with the first name of your five closest friends in one statement (statically)
friend_list = 

print(friend_list)


#now delcare a list of their last names dynamically (hint: use the .append() function)

last_name = []

last_name.append(      )




print(last_name)



a = 12
b = 12

#This print statement will print True or False? _______
print(a == b)



#fill in the code to print "num is even" if the i is even and "num is odd" if i is odd
for i in range(0,10):
  if( i % __ ): 
    print("num is even")
  else:
    print("num is odd")


#fill in the code to print the names of the legends that end in "seus" using at least one continue statement 
legends = ["Jason", "Hercules", "Theseus", "Perseus", "Odysseus", "Achilles"]

for(i in legends):
  if

# %% [markdown]
# #**Dictionaries**

# %% [markdown]
# Last Session we looked at a few ways data was stored in Python (variables, list…)
# Dictionaries are another way to store data in python <br/>
# Dictionaries work like maps in other languages and are built to support key/value pairs, removal, insertion, and searching
# Dictionaries are kind of like lists and arrays except the elements are stored in pairs<br/>
# Elements are stored with a Key(K) and a Value(V). The Key is used to as the index of the Value in the Dictionary
# A dictionary is statically declared like:  <br/> <br/> ```
# dict_name = { K : V, K : V, K : V}
# ```

# %%
#Run this code to see how dictionaries are printed

Directory  = {
    "Corey" : "cfulle3",
    "Joe" : "mama",
    "Jared" : "jgwentworth"
}
print(Directory)

# %% [markdown]
# Dictionaries do not have to be declared in one instance.<br/>
# You can give your dictionary a name and add elements to it dynamically.<br/>
# ```
# Directory = {}
# Directory["Corey"] = “cfulle3”
# Directory["Jared"] = “jgwentworth”
# Directory["Joe"] = “mama”
# print(Directory)
# ```
# The Key and Values in a dictionary can be any data type and do not have to be the same data type as each other. Ex. String : int, int : list <br/>
# Iterating over a dictionary is done using ranged-based for loops.<br/>
# Deleting elements in a dictionary is as simple as using the del keyword or the .pop() function like with lists.

# %%
# Declare a dictionary with 5 elements.
# The key will be a string for a first name and the value will be a string that represents a 10 digit phone number

Phonebook = 

#in the brackets put in one of the names in string format "  "
print(Phonebook[ ])

#Why does this work?
for names, numbers in Phonebook:
  print("%s has the number %s", names, numbers)

# %% [markdown]
# #**Functions**

# %% [markdown]
# Python allows for the use of functions just like many other functions. <br/>
# Functions are declared using the “def” keyword<br/>
# ```Def my_funct()```<br/>
# Instead of curly braces, we use “:” after the function definition and indentation to indicate what code belongs to the function. <br/>
# Functions in python do not have a return type in the signature or the data type of the parameters.<br/>
# To return data from the function you just use the “return” keyword

# %%
a = 5
b = 6

def add(a,b):
  #fill in the code to return the sum of a and b
  return

# %%
# how to declare a main function in python


# 3 regular functions
def func1():
  print("One function")

def func2():
  print("Another function")

def func3():
  print("....Another function???")


# main calling the functions above
def main():
  func1()
  func2()
  func3()

# calling main
if __name__ == '__main__':
  main()
# Out:
# One function
# Another function
# ....Another function???

# %% [markdown]
# #**Classes and Objects**

# %% [markdown]
# Without prior object oriented programming experience, objects and classes can be a little tricky to grasp.<br/>
# Hopefully most of you have had some experience with an object-oriented language. (C++, Java, C#, Python)<br/>
# Classes serve as a blueprint for objects, and objects are made through grouping of related data and functions in a single entity known as **encapsulation**.<br/>
# If you’ve done OOP before great, if you haven’t that’s fine.
# Hopefully the worksheet will provide enough practice.

# %% [markdown]
# ##**Classes**

# %% [markdown]
# Classes are declared using the “class” keyword.<br/>
# All class members in python default to public.<br/>
# The “self” keyword is used so we can reference the data in the object itself.<br/>

# %%
class Triangle:
  base = 12
  height = 3
  
  #fill in the member variable names to calcuate the area
  def calcArea(self):
   return (1/2) * self.  *  self.

# %% [markdown]
# ##**Objects**
# Objects are just instances of a class.<br/>
# They have their own copies of the data inside of the class
# Multiple objects can be created from the same class
# Objects are declared like:
# 		```myObject = myClass()```<br/>
# The parentheses next to class name are just constructor calls and can take parameters if a parameterized constructor is defined for a class.

# %%
class Triangle:
  base = 12
  height = 3
  
  #constructor
  def __init__(self, b, h):
    #sets the base and height of the triangle
    self.base = b
    self.height = h

  def calcArea(self):
   return (1/2) * self.base  *  self.height


triangle = Triangle(4,6)
print(triangle.calcArea())

#create a 4 more triangle objects with different bases and heights
triangle1 = Triangle( , )
print(triangle1.calcArea())

triangle2 = Triangle( , )
print(triangle2.calcArea())

triangle3 = Triangle( , )
print(triangle3.calcArea())

triangle4 = Triangle( , )
print(triangle4.calcArea())

# %% [markdown]
# #**Challenge Exercise for Extra Credit**

# %%
import random as random

class Square:
  length = 0
  width = 0

  def __init__(self, l, w):
    self.length = l
    self.width = w

  # Fill in the code to find the perimeter of a square
  def findPerimeter(self):
    return 

   # Fill in the code to find the area of a square
  def findArea(self):
    return 



def main():
  #Create 5 Square objects with different width and heights passed to the constructor
  #name them square1.....square5
  square1 = 


  #Create a dictionary with the Key being a string of the "square name + what's being calculated in the pair
  #have the value be a call to either functio
  
   *Name the dictionary* = {
       #don't forget commas
      "square1 Perimeter" : square1.findPerimeter(),
    
  }

  #print the dictionary

if __name__ == '__main__':
  main()
# Out:
# {'square1 Perimeter': 10, 'square2 Area': 12}

# %% [markdown]
# **Paste the value from the last element of the dictionary for extra credit!!!**
